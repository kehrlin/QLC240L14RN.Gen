# %% [markdown]
# <a href="https://colab.research.google.com/github/kehrlin/QLC240L14RN.Gen/blob/main/Excercise_1_and_two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Excercise one

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
import requests
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/seina001/QLC240_Spring2025/refs/heads/main/Excercise1_data.txt", delimiter="\t")
print(data)
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0             0                5.1               3.5                1.4
# 1             1                4.9               3.0                1.4
# 2             2                4.7               3.2                1.3
# 3             3                4.6               3.1                1.5
# 4             4                5.0               3.6                1.4
# ..          ...                ...               ...                ...
# 145         145                6.7               3.0                5.2
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)  target
# 0                 0.2       0
# 1                 0.2       0
# ...

# %%
from sklearn.datasets import load_iris

iris = load_iris()
iris_fromdata = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_fromdata.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_fromdata.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
plot = iris_fromdata.hist()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
plot = sns.pairplot(iris_fromdata)

# %%
plot=sns.boxplot(data=iris_fromdata)

# %%
plot=sns.scatterplot(data=iris_fromdata)

# %% [markdown]
# *Finally, write a reflection on this excercise. What was easy, what was hard, what didn't work the first time, what errors did you encouter, etc.*
#
# this excercise took a while to get the hang of, especially adding the delimeter on my initial dataset upload. That took a lot of tiral and error. But once I got that done it was relatively easy to make sure that I got everything else done, I took an HTML and Python class in High school, and while they are very different, I think I still remember some of the basics.

# %% [markdown]
# # Excercise two

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
iris_df['species'] = iris.target

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
import matplotlib.pyplot as plt
iris_df.hist(figsize=(10, 6))
plt.show()

# %%
sns.pairplot(iris_df, hue='species' )
plt.show()

# %%
import matplotlib.pyplot as plt
# Add target variable to the dataframe
iris_df['species'] = iris.target_names[iris.target]

sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
plt.show()
